# %%
import pandas as pd
from Agent import SupportAgent

abc_data = pd.read_csv(r"C:\Users\MITHUN\Desktop\STUDIES\Drive\Akaike\Problem-B\dataset\customer_support_tickets.csv")

abc_agent = SupportAgent()

for _, abc_row in abc_data.head(5).iterrows():
    abc_ticket = abc_row.to_dict()
    abc_result = abc_agent.process_ticket(abc_ticket)
    print(abc_result)
# Out:
# {'ticket_id': 1, 'department': 'Billing', 'priority': 'Low', 'sentiment': 'Satisfied', 'entities': {}, 'suggested_response': 'Dear Marisa Obrien,\n\n\nThank you for contacting us.\n\nYour issue has been routed to our Billing department with Low priority.\n\nSuggested Help:\nOur team will review your issue and get back shortly.\n\nPlease let us know if you need further assistance.\n\nBest Regards,\nSupport Team', 'escalation_required': False, 'reasoning': 'Routed to Billing due to keyword detection. Priority set to Low based on urgency and sentiment.'}
# ...
